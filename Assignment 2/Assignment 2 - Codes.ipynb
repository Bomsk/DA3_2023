# %% [markdown]
# # Importing libraries, Examining data

# %%
import os
import pandas as pd
import numpy as np
import sys
import patsy
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression, LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
import sklearn.metrics as metrics
from sklearn.metrics import brier_score_loss, roc_curve, auc, confusion_matrix, roc_auc_score, mean_squared_error
from sklearn.ensemble import RandomForestClassifier
from plotnine import *
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %%
# Read csv
originaldf = pd.read_csv('https://raw.githubusercontent.com/Bomsk/DA3_2023/main/Assignment%202/listings.csv')

# %%
# Checking dataset
originaldf
# Out:
#                         id                                       listing_url  \
# 0                   197677               https://www.airbnb.com/rooms/197677
# 1                   776070               https://www.airbnb.com/rooms/776070
# 2                   905944               https://www.airbnb.com/rooms/905944
# 3                  1016831              https://www.airbnb.com/rooms/1016831
# 4                  3838856              https://www.airbnb.com/rooms/3838856
# ...                    ...                                               ...
# 13720  1052613009241026699  https://www.airbnb.com/rooms/1052613009241026699
# 13721  1052618956131641134  https://www.airbnb.com/rooms/1052618956131641134
# 13722  1052621352644395645  https://www.airbnb.com/rooms/1052621352644395645
# 13723  1052624489140939071  https://www.airbnb.com/rooms/1052624489140939071
# 13724  1052625043632002469  https://www.airbnb.com/rooms/1052625043632002469
#
# ...

# %%
# Drop rows with missing price
df = originaldf.dropna(subset=['price'])

# %%
df
# Out:
#                         id                                       listing_url  \
# 0                   197677               https://www.airbnb.com/rooms/197677
# 1                   776070               https://www.airbnb.com/rooms/776070
# 2                   905944               https://www.airbnb.com/rooms/905944
# 4                  3838856              https://www.airbnb.com/rooms/3838856
# 5                  1196177              https://www.airbnb.com/rooms/1196177
# ...                    ...                                               ...
# 13720  1052613009241026699  https://www.airbnb.com/rooms/1052613009241026699
# 13721  1052618956131641134  https://www.airbnb.com/rooms/1052618956131641134
# 13722  1052621352644395645  https://www.airbnb.com/rooms/1052621352644395645
# 13723  1052624489140939071  https://www.airbnb.com/rooms/1052624489140939071
# 13724  1052625043632002469  https://www.airbnb.com/rooms/1052625043632002469
#
# ...

# %%
# Clean the price column
df["price"] = df["price"].replace('[\$,]', '', regex=True).astype(float)

# %%
# Filter 'accommodates' for 2-6 people
# df[(df['accommodates'] >= 2) & (df['accommodates'] <= 6)]
df.loc[(df['accommodates'] >= 2) & (df['accommodates'] <= 6)]['accommodates'].value_counts()
# Out:
# accommodates
# 2    3616
# 3    2347
# 4    2263
# 6    1248
# 5     902
# Name: count, dtype: int64

# %%
df = df.loc[(df['accommodates'] >= 2) & (df['accommodates'] <= 6)]

# %%
# not hotel room
df = df.loc[df['room_type'] != "Hotel room"]
